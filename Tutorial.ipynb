# %% [markdown]
# # LastStickerStat и LastStickerBot

# %% [markdown]
# Класс **LastStickerStat** - это инструмент для парсинга и обработки данных по лотам сайта коллекционеров [laststicker.ru](https://www.laststicker.ru/)
# Он может работать как самостоятельно, так и в "тандеме" с телеграм ботом. Последнее не требует у пользователя програмистских навыков и позволяет обновлять данные и делать запросы к их базе, ограничиваясь командами бота и интуитивно понятным "языком" фильтрации, разработанным специально под эти цели.

# %% [markdown]
# *Зачем оно нужно и что дает?*
#
# К сожалению, у [laststicker.ru](https://www.laststicker.ru/) нет большого архива лотов (есть только архив лотов, которые закрылись за последний месяц) и информации о продажах (кто и кому продал определенный предмет, когда, за сколько и т. д.).
#
# К счастью, старые лоты (недоступные через интерфейс) можно открывать по ссылкам вида `www.laststicker.ru/auction/post{id}`, что и дает возможность парсинга.
#
# Поэтому доступ к этой большой базе (насчитывающей более 400К лотов) и поиску по ней дает:
# - возможность найти информацию о том, кому была продана определенная (желанная пользователю) вещь (коллекционный журнал, карточка, наклейка или их блок и т. д.) и договориться о перекупе
# - возможность анализировать информацию о тенденции цен по коллекциям/предметам/... (если пользователь занимается коллекционным бизнесом или инвестированием в эту сферу с целью долгосрочного дохода)
# - понимание, как общаться с клиентом/продавцом на сделке (можно ли торговаться, например), учитывая то, по каким ценам он покупал/продавал предметы ранее
# - делать разные выводы, основываясь на статистических данных, и многое другое!

# %%
from LastStickerStat import *

# %% [markdown]
# Пусть база уже существует и находится в папке *data* или базы еще нет, и мы хотим, чтобы она загрузилась в эту папку (очень желательно, чтобы она была пустая, т.к. если в дальнейшем захочется запустить бота на этих данных, то пользователи со *специальным доступом* смогут выгружать архив всей папки).
# *Убедитесь, что в папке с LastStickerStat.py находится `config.json`. Он необходим, как минимум, для правильной работы парсинга. Изменения данных этого файла может привести к непредвиденным последствиям!

# %% [markdown]
# (То же самое можно сделать, **запустив скрипт** `python3 LastStickerStat.py data`, только это имеет смысл, если мы создаем базу с нуля)

# %% [markdown]
# **Имейте в виду, что если базы еще не существует, то все 400К+ лотов будут загружаться 15-25 часов в зависимости от скорости вашего интернета**
#
# Создаем объект класса `LastStickerStat`:

# %%
stat = LastStickerStat("data")

# %% [markdown]
# Для удобства я добавила графический ползунок процента загрузки. Если базы не было или мы специально создаем ее по новой, будет 2 ползунка: первый информирует о проценте загрузки данных "старого" формата, второй - "нового".
# Я их так назвала просто потому, что лоты до, примерно, 2014 года выглядят (а главное, размечены в html) одним образом, а после - другим. Пример ["старого"](https://www.laststicker.ru/blog/post10112/) (ставки делаются в комментариях, без ML, кажется, в основном нельзя понять, выкупили ли лот, если да, кто и по какой цене) формата и ["нового"](https://www.laststicker.ru/auction/post484105/) (у таких страниц +- строгая разметка и достаточно легко выпарсить, что нужно).
# Староформатные лоты помечаются в базе флажком "Староформатный" в колонке lot_type и кроме названия лота, дат открытия/закрытия лота, информации о продавце и коллекции никакой особо содержательной информации больше не записывается. Т.к. лотов такого типа относительно мало и в основном база создавалась под нужды определенного человека, которого устроила такая ситуация, то и меня это устроило.

# %% [markdown]
# Теперь, когда обьект `stat` инициализирован, у него есть несколько информационных атрибутов, в числе которых:

# %%
print(stat.csv_path) # путь к нашей базе в csv формате
print(stat.upper_csv_path) # путь к "базе верхних регистров"; не несет никакой новой информации, создана для
                           # более быстрого и простого поиска лотов по подстрокам
print(stat.info["last_lot_parse_date"]) # дата и время последнего обновления базы
stat.df # DataFrame наших данных
# Out:
# data/data.csv
# data/upper_data.csv
# 10:5 28.1.2022
#                                                     title  \
# 0                    черепашки ниндзя (часть 1-ая из 2-х)
# 1       Полный комплект наклеек Panini NHL 95-96. 306 ...
# 2                                    Panini Пикси / Pixie
# 3       Продаётся на 100% заполненный альбом Панда Кун...
# 4       Куплю любое количество стикеров РФПЛ 2009 в пр...
# ...                                                   ...
# 474893     Почти пустой альбом Panini Утиные истории 1987
# 474894                           Альбом Mickey Story 1978
# 474895  12 разных наклеек по коллекции Panini Белоснеж...
# 474896  Продажа 206 стикеров без повторов по коллекции...
# 474897  4 блока в заводской упаковке + подарок по колл...
#
#                                                    url       subject  \
# 0         https://www.laststicker.ru/auction/post3982/  Неопределено
# 1         https://www.laststicker.ru/auction/post3983/      Наклейки
# 2         https://www.laststicker.ru/auction/post3984/      Наклейки
# 3         https://www.laststicker.ru/auction/post3985/      Наклейки
# 4         https://www.laststicker.ru/auction/post3987/      Наклейки
# ...                                                ...           ...
# 474893  https://www.laststicker.ru/auction/post484168/      Наклейки
# 474894  https://www.laststicker.ru/auction/post484169/      Наклейки
# 474895  https://www.laststicker.ru/auction/post484170/      Наклейки
# 474896  https://www.laststicker.ru/auction/post484171/      Наклейки
# 474897  https://www.laststicker.ru/auction/post484172/      Наклейки
#
#                       theme        lot_type  status is_bet_made  \
# 0        Мультфильмы и кино  Староформатный  Закрыт         NaN
# 1        Хоккейные наклейки  Староформатный  Закрыт         NaN
# 2        Мультфильмы и кино  Староформатный  Закрыт         NaN
# 3        Мультфильмы и кино  Староформатный  Закрыт         NaN
# 4       Футбольные наклейки  Староформатный  Закрыт         NaN
# ...                     ...             ...     ...         ...
# 474893   Мультфильмы и кино         Аукцион  Открыт       False
# 474894   Мультфильмы и кино         Аукцион  Открыт       False
# 474895   Мультфильмы и кино         Аукцион  Открыт       False
# 474896   Хоккейные наклейки         Аукцион  Открыт       False
# 474897   Хоккейные наклейки         Аукцион  Открыт       False
#
#                                      collection  \
# 0                                           NaN
# 1                          PANINI NHL 1995-1996
# 2                                  PANINI Пикси
# 3                             АСТ Кунг-Фу Панда
# 4       Российская Футбольная Премьер-Лига 2009
# ...                                         ...
# 474893                    PANINI Утиные истории
# 474894                      PANINI Mickey Story
# 474895             PANINI Белоснежка и 7 гномов
# 474896                     SeReal КХЛ 2011-2012
# 474897                     PANINI КХЛ 2017-2018
#
#                                            url_collection  date_start_day  \
# 0                                                     NaN              17
# 1       https://www.laststicker.ru/cards/panini_nhl_95...              17
# 2          https://www.laststicker.ru/cards/panini_pixie/              18
# 3       https://www.laststicker.ru/cards/ast_kung_fu_p...              18
# 4       https://www.laststicker.ru/cards/sportssticker...              18
# ...                                                   ...             ...
# 474893  https://www.laststicker.ru/cards/panini_duck_t...              28
# 474894  https://www.laststicker.ru/cards/panini_mickey...              28
# 474895  https://www.laststicker.ru/cards/panini_snow_w...              28
# 474896  https://www.laststicker.ru/cards/sereal_khl_20...              28
# 474897  https://www.laststicker.ru/cards/panini_khl_20...              28
#
#         ...  seller_location_district  seller_location_country initial_price  \
# 0       ...                       NaN                      NaN           NaN
# 1       ...                       NaN                      NaN           NaN
# 2       ...                       NaN                      NaN           NaN
# 3       ...                       NaN                      NaN           NaN
# 4       ...                       NaN                      NaN           NaN
# ...     ...                       ...                      ...           ...
# 474893  ...        Забайкальский край                   Россия         699.0
# 474894  ...        Забайкальский край                   Россия         699.0
# 474895  ...        Забайкальский край                   Россия         180.0
# 474896  ...      Владимирская область                   Россия         150.0
# 474897  ...      Владимирская область                   Россия         950.0
#
#        last_price last_price_author url_last_buyer date_end_day  \
# 0             NaN               NaN            NaN          NaN
# 1             NaN               NaN            NaN          NaN
# 2             NaN               NaN            NaN          NaN
# 3             NaN               NaN            NaN          NaN
# 4             NaN               NaN            NaN          NaN
# ...           ...               ...            ...          ...
# 474893        NaN               NaN            NaN          2.0
# 474894        NaN               NaN            NaN          1.0
# 474895        NaN               NaN            NaN          1.0
# 474896        NaN               NaN            NaN          4.0
# 474897        NaN               NaN            NaN          4.0
#
#        date_end_month  date_end_year  date_end_time
# 0                 NaN            NaN            NaN
# 1                 NaN            NaN            NaN
# 2                 NaN            NaN            NaN
# 3                 NaN            NaN            NaN
# 4                 NaN            NaN            NaN
# ...               ...            ...            ...
# 474893            2.0         2022.0          15:00
# 474894            2.0         2022.0          15:00
# 474895            2.0         2022.0          15:00
# 474896            2.0         2022.0          09:48
# 474897            2.0         2022.0          09:52
#
# [474898 rows x 26 columns]

# %% [markdown]
# Теперь таблицу можно анализировать руками с помощью функционала pandas. Для начала посмотрим, какими вообще могут быть значения колонок с ограниченным набором значений

# %%
print("subject = ", stat.df.subject.unique())
print("\ntheme = ", stat.df.theme.unique())
print("\nlot_type = ", stat.df.lot_type.unique())
print("\nstatus = ", stat.df.status.unique())
print("\nis_bet_made = ", stat.df.is_bet_made.unique())
# Out:
# subject =  ['Неопределено' 'Наклейки' 'Карточки' 'Другое']
#
# theme =  ['Мультфильмы и кино' 'Хоккейные наклейки' 'Футбольные наклейки' 'ККИ'
#  'Прочие наклейки' 'Прочее' 'Другие виды спорта' 'Аксессуары'
#  'Совместные заказы' 'Футбольные карточки' 'Хоккейные карточки'
#  'Прочие карточки' 'Монеты, купюры' 'Значки' 'Марки' 'Печатная продукция'
#  'Модели']
#
# lot_type =  ['Староформатный' 'Аукцион' 'Объявление']
#
# status =  ['Закрыт' 'Открыт']
#
# is_bet_made =  [nan True False]

# %% [markdown]
# Остальные колонки, как можно видеть из `DataFrame`, это либо строки, либо числа (либо `NaN`). У каждого лота свои  Вообще говоря, названия колонок достаточно хорошо передают их суть, поэтому должно быть понятно, какие данные будут в каждом столбце
#
# Функционал объекта класса `LastStickerStat`, который не "привязан" к определенному боту, довольно ограничен. Можно руками получить любой желаемый срез данных, например:

# %%
WIZARDS Гарри Поттер и Философский Камень - Ки...
# 415493  WIZARDS Гарри Поттер и Философский Камень - Ки...
# 423273    ARTBOX Гарри Поттер. Памятные моменты (2 часть)
# 425523    ARTBOX Гарри Поттер и Узник Азкабана. FilmCardz
# 435447  WIZARDS Гарри Поттер и Философский Камень - Ки...
# 447372     ARTBOX Гарри Поттер и Узник Азкабана (2 часть)
# 450667  WIZARDS Гарри Поттер и Философский Камень - Ки...
# 455908  WIZARDS Гарри Поттер и Философский Камень - Ки...
# 462475  WIZARDS Гарри Поттер и Философский Камень - Ки...
# 470660  WIZARDS Гарри Поттер и Философский Камень - Ки...
# 472062  WIZARDS Гарри Поттер и Философский Камень - Ки...
#
#                                            url_collection  date_start_day  \
# 116573  https://www.laststicker.ru/cards/wizards_harry...              10
# 116574  https://www.laststicker.ru/cards/cards_harry_p...              10
# 168239  https://www.laststicker.ru/cards/artbox_harry_...               2
# 183023  https://www.laststicker.ru/cards/wizards_harry...               7
# 232617  https://www.laststicker.ru/cards/wizards_harry...               1
# 234027  https://www.laststicker.ru/cards/wizards_harry...              12
# 244626  https://www.laststicker.ru/cards/wizards_harry...              28
# 247016  https://www.laststicker.ru/cards/wizards_harry...              12
# 276162  https://www.laststicker.ru/cards/artbox_harry_...              12
# 285222  https://www.laststicker.ru/cards/artbox_harry_...              28
# 320707  https://www.laststicker.ru/cards/wizards_harry...              26
# 333971  https://www.laststicker.ru/cards/artbox_harry_...               3
# 337685  https://www.laststicker.ru/cards/artbox_harry_...              24
# 341934  https://www.laststicker.ru/cards/artbox_harry_...              24
# 350996  https://www.laststicker.ru/cards/artbox_harry_...              19
# 381684  https://www.laststicker.ru/cards/artbox_harry_...              12
# 388826  https://www.laststicker.ru/cards/artbox_harry_...              21
# 394867  https://www.laststicker.ru/cards/artbox_harry_...              22
# 406941  https://www.laststicker.ru/cards/wizards_harry...               2
# 415493  https://www.laststicker.ru/cards/wizards_harry...              15
# 423273  https://www.laststicker.ru/cards/artbox_harry_...              23
# 425523  https://www.laststicker.ru/cards/artbox_harry_...               3
# 435447  https://www.laststicker.ru/cards/wizards_harry...               4
# 447372  https://www.laststicker.ru/cards/artbox_harry_...               3
# 450667  https://www.laststicker.ru/cards/wizards_harry...              17
# 455908  https://www.laststicker.ru/cards/wizards_harry...               9
# 462475  https://www.laststicker.ru/cards/wizards_harry...               5
# 470660  https://www.laststicker.ru/cards/wizards_harry...              12
# 472062  https://www.laststicker.ru/cards/wizards_harry...              17
#
#         ...  seller_location_district  seller_location_country initial_price  \
# 116573  ...     Нижегородская область                   Россия         500.0
# 116574  ...     Нижегородская область                   Россия         500.0
# 168239  ...        Московская область                   Россия         400.0
# 183023  ...        Московская область                   Россия         790.0
# 232617  ...                 Татарстан                   Россия          80.0
# 234027  ...                 Татарстан                   Россия          80.0
# 244626  ...          Хабаровский край                   Россия         500.0
# 247016  ...       Воронежская область                   Россия         500.0
# 276162  ...        Московская область                   Россия         333.0
# 285222  ...          Тверская область                   Россия          50.0
# 320707  ...        Пензенская область                   Россия         500.0
# 333971  ...        Московская область                   Россия         100.0
# 337685  ...        Московская область                   Россия         100.0
# 341934  ...        Московская область                   Россия         100.0
# 350996  ...        Московская область                   Россия          80.0
# 381684  ...        Московская область                   Россия           1.0
# 388826  ...        Московская область                   Россия         500.0
# 394867  ...        Московская область                   Россия          80.0
# 406941  ...                       NaN                  Украина          10.0
# 415493  ...       Воронежская область                   Россия         100.0
# 423273  ...       Саратовская область                   Россия        1000.0
# 425523  ...        Московская область                   Россия          79.0
# 435447  ...       Воронежская область                   Россия         100.0
# 447372  ...                       NaN                Казахстан         650.0
# 450667  ...       Воронежская область                   Россия         100.0
# 455908  ...       Воронежская область                   Россия         150.0
# 462475  ...          Тульская область                   Россия          50.0
# 470660  ...                       NaN                  Украина         150.0
# 472062  ...          Тульская область                   Россия          25.0
#
#        last_price last_price_author                           url_last_buyer  \
# 116573      580.0            VitVit  https://www.laststicker.ru/users/36590/
# 116574     1050.0         cergei-75  https://www.laststicker.ru/users/51910/
# 168239      420.0           Артур М  https://www.laststicker.ru/users/57773/
# 183023      830.0       Tanya-Tanya  https://www.laststicker.ru/users/60216/
# 232617       89.0        Shikrokami  https://www.laststicker.ru/users/41094/
# 234027       84.0      ден супермен  https://www.laststicker.ru/users/60610/
# 244626      500.0           NinaSon  https://www.laststicker.ru/users/61258/
# 247016      500.0             Dredd  https://www.laststicker.ru/users/38492/
# 276162      333.0         papa_john    https://www.laststicker.ru/users/291/
# 285222      460.0           Sanchel  https://www.laststicker.ru/users/31201/
# 320707      500.0             busel  https://www.laststicker.ru/users/16516/
# 333971      105.0            VitVit  https://www.laststicker.ru/users/36590/
# 337685      121.0           Origami  https://www.laststicker.ru/users/56455/
# 341934      100.0         Николай96  https://www.laststicker.ru/users/58341/
# 350996       80.0         tankttbtv  https://www.laststicker.ru/users/66011/
# 381684      609.0           Пиранья  https://www.laststicker.ru/users/61228/
# 388826      500.0              dfyz   https://www.laststicker.ru/users/4957/
# 394867       80.0             рыбка   https://www.laststicker.ru/users/5722/
# 406941       10.0          Slavik84  https://www.laststicker.ru/users/17537/
# 415493      105.0          philjack  https://www.laststicker.ru/users/60386/
# 423273     1000.0    Protasova Lena  https://www.laststicker.ru/users/76255/
# 425523       79.0           Julia77  https://www.laststicker.ru/users/19502/
# 435447      179.0            Fafnir  https://www.laststicker.ru/users/81423/
# 447372      650.0    Protasova Lena  https://www.laststicker.ru/users/76255/
# 450667      277.0            Fafnir  https://www.laststicker.ru/users/81423/
# 455908      204.0          philjack  https://www.laststicker.ru/users/60386/
# 462475       69.0    ОлегНиколаевич  https://www.laststicker.ru/users/42353/
# 470660      150.0       FaraonCards  https://www.laststicker.ru/users/82364/
# 472062       31.0          ValerieB  https://www.laststicker.ru/users/80273/
#
#        date_end_day date_end_month  date_end_year  date_end_time
# 116573         11.0           11.0         2015.0          22:22
# 116574         11.0           11.0         2015.0          22:41
# 168239          4.0            1.0         2017.0          22:50
# 183023         14.0            4.0         2017.0          21:37
# 232617          8.0            4.0         2018.0          17:04
# 234027         13.0            4.0         2018.0          12:30
# 244626          4.0            7.0         2018.0          21:00
# 247016         18.0            7.0         2018.0          23:00
# 276162         15.0            1.0         2019.0          20:57
# 285222          4.0            3.0         2019.0          18:01
# 320707         29.0            9.0         2019.0          23:00
# 333971          6.0           12.0         2019.0          21:04
# 337685         27.0           12.0         2019.0          21:00
# 341934         28.0            1.0         2020.0          21:00
# 350996         22.0            3.0         2020.0          21:00
# 381684         19.0           10.0         2020.0          20:01
# 388826         23.0           11.0         2020.0          21:00
# 394867         25.0           12.0         2020.0          21:00
# 406941          9.0            3.0         2021.0          15:56
# 415493         18.0            4.0         2021.0          21:30
# 423273         29.0            5.0         2021.0          21:00
# 425523          7.0            6.0         2021.0          21:00
# 435447          8.0            8.0         2021.0          21:33
# 447372         10.0           10.0         2021.0          19:25
# 450667         22.0           10.0         2021.0          21:35
# 455908         15.0           11.0         2021.0          21:35
# 462475         12.0           12.0         2021.0          22:08
# 470660         19.0            1.0         2022.0          12:35
# 472062         23.0            1.0         2022.0          22:00
#
# [29 rows x 26 columns]

# %% [markdown]
# В базе есть много карточек и наклеек фирмы Panini, но в разных лотах она может быть написана в разных регистрах. Найдем все лоты, которые имеют отношение к этой фирме, используя вспомогательную таблицу верхних регистров `stat.df_upper`

# %%
word = "Panini"
stat.df.loc[stat.df_upper[(stat.df_upper.collection.str.contains(word.upper()) == True) | (stat.df_upper.title.str.contains(word.upper()) == True)].index]
# Out:
#                                                     title  \
# 1       Полный комплект наклеек Panini NHL 95-96. 306 ...
# 2                                    Panini Пикси / Pixie
# 5                               Евро-96 собранный на 96%.
# 7                    Куплю Альбом+2 блока World Cup STORY
# 8                            Чемпионат Мира 1998 (Pаnini)
# ...                                                   ...
# 474892               Заполненный альбом Panini Король Лев
# 474893     Почти пустой альбом Panini Утиные истории 1987
# 474894                           Альбом Mickey Story 1978
# 474895  12 разных наклеек по коллекции Panini Белоснеж...
# 474897  4 блока в заводской упаковке + подарок по колл...
#
#                                                    url   subject  \
# 1         https://www.laststicker.ru/auction/post3983/  Наклейки
# 2         https://www.laststicker.ru/auction/post3984/  Наклейки
# 5         https://www.laststicker.ru/auction/post3993/  Наклейки
# 7         https://www.laststicker.ru/auction/post4003/  Наклейки
# 8         https://www.laststicker.ru/auction/post4004/  Наклейки
# ...                                                ...       ...
# 474892  https://www.laststicker.ru/auction/post484167/  Наклейки
# 474893  https://www.laststicker.ru/auction/post484168/  Наклейки
# 474894  https://www.laststicker.ru/auction/post484169/  Наклейки
# 474895  https://www.laststicker.ru/auction/post484170/  Наклейки
# 474897  https://www.laststicker.ru/auction/post484172/  Наклейки
#
#                       theme        lot_type  status is_bet_made  \
# 1        Хоккейные наклейки  Староформатный  Закрыт         NaN
# 2        Мультфильмы и кино  Староформатный  Закрыт         NaN
# 5       Футбольные наклейки  Староформатный  Закрыт         NaN
# 7       Футбольные наклейки  Староформатный  Закрыт         NaN
# 8       Футбольные наклейки  Староформатный  Закрыт         NaN
# ...                     ...             ...     ...         ...
# 474892   Мультфильмы и кино         Аукцион  Открыт       False
# 474893   Мультфильмы и кино         Аукцион  Открыт       False
# 474894   Мультфильмы и кино         Аукцион  Открыт       False
# 474895   Мультфильмы и кино         Аукцион  Открыт       False
# 474897   Хоккейные наклейки         Аукцион  Открыт       False
#
#                              collection  \
# 1                  PANINI NHL 1995-1996
# 2                          PANINI Пикси
# 5          PANINI Чемпионат Европы 1996
# 7       PANINI История Чемпионатов Мира
# 8            PANINI Чемпионат Мира 1998
# ...                                 ...
# 474892                PANINI Король Лев
# 474893            PANINI Утиные истории
# 474894              PANINI Mickey Story
# 474895     PANINI Белоснежка и 7 гномов
# 474897             PANINI КХЛ 2017-2018
#
#                                            url_collection  date_start_day  \
# 1       https://www.laststicker.ru/cards/panini_nhl_95...              17
# 2          https://www.laststicker.ru/cards/panini_pixie/              18
# 5       https://www.laststicker.ru/cards/panini_euro_1...              18
# 7       https://www.laststicker.ru/cards/panini_wc_story/              19
# 8        https://www.laststicker.ru/cards/panini_wc_1998/              19
# ...                                                   ...             ...
# 474892  https://www.laststicker.ru/cards/panini_lion_k...              28
# 474893  https://www.laststicker.ru/cards/panini_duck_t...              28
# 474894  https://www.laststicker.ru/cards/panini_mickey...              28
# 474895  https://www.laststicker.ru/cards/panini_snow_w...              28
# 474897  https://www.laststicker.ru/cards/panini_khl_20...              28
#
#         ...  seller_location_district  seller_location_country initial_price  \
# 1       ...                       NaN                      NaN           NaN
# 2       ...                       NaN                      NaN           NaN
# 5       ...                       NaN                      NaN           NaN
# 7       ...                       NaN                      NaN           NaN
# 8       ...                       NaN                      NaN           NaN
# ...     ...                       ...                      ...           ...
# 474892  ...        Забайкальский край                   Россия        3200.0
# 474893  ...        Забайкальский край                   Россия         699.0
# 474894  ...        Забайкальский край                   Россия         699.0
# 474895  ...        Забайкальский край                   Россия         180.0
# 474897  ...      Владимирская область                   Россия         950.0
#
#        last_price last_price_author url_last_buyer date_end_day  \
# 1             NaN               NaN            NaN          NaN
# 2             NaN               NaN            NaN          NaN
# 5             NaN               NaN            NaN          NaN
# 7             NaN               NaN            NaN          NaN
# 8             NaN               NaN            NaN          NaN
# ...           ...               ...            ...          ...
# 474892        NaN               NaN            NaN          2.0
# 474893        NaN               NaN            NaN          2.0
# 474894        NaN               NaN            NaN          1.0
# 474895        NaN               NaN            NaN          1.0
# 474897        NaN               NaN            NaN          4.0
#
#        date_end_month  date_end_year  date_end_time
# 1                 NaN            NaN            NaN
# 2                 NaN            NaN            NaN
# 5                 NaN            NaN            NaN
# 7                 NaN            NaN            NaN
# 8                 NaN            NaN            NaN
# ...               ...            ...            ...
# 474892            2.0         2022.0          15:00
# 474893            2.0         2022.0          15:00
# 474894            2.0         2022.0          15:00
# 474895            2.0         2022.0          15:00
# 474897            2.0         2022.0          09:52
#
# [258765 rows x 26 columns]

# %% [markdown]
# Еще можно загрузить результаты поиска в *csv*, открыть в Excel (LibreOffice и др.) и просмотреть найденные лоты глазами

# %%
path = "filtered_{}.csv".format(stat.dir_path)
df.to_csv(path, index=False, sep=";") # результат поиска лотов по Поттеру
print("Отфильтрованные данные находятся в файле {}".format(path))
# Out:
# Отфильтрованные данные находятся в файле filtered_test9.csv

# %% [markdown]
# Также, можно обновлять данные в базе: менять статус лота с *Открыт* на *Закрыт*, если лот закрылся, подгружать новую информацию о ставках, покупателях и т.д., и загружать информацию о новых, недавно открывшихся лотах

# %%
date, url, lots = stat.update()
print("Данные актуальны на {}.\nПоследний загруженный лот - {}.\nВсего новых лотов : {}".format(date, url, lots))
# Out:
# 100%|██████████| 2349/2349 [02:04<00:00, 18.92it/s]
# 0it [00:00, ?it/s]
# Данные актуальны на 2:8 28.1.2022.
# Последний загруженный лот - https://www.laststicker.ru/auction/post484154/.
# Всего новых лотов : 0

# %% [markdown]
# Это весь функционал, доступный для использования без телеграм бота.

# %% [markdown]
# В данный момент бот крутится на Google Platform сервере и еще будет крутится пару месяцев, пока не закончится бесплатный период. Поэтому функционал бота можно потестировать двумя способами:
# **1)** Найти в телеграме [@LastStickerStatBot](https://t.me/LastStickerStatBot), нажать старт и дождаться пока я (мне прилетит ваш id) дам вам доступ (я могу раздавать доступ также через телеграм). Это делается нажатием одной команды, поэтому если я не буду спать в то время, как вы кликните /start, доступ у вас будет моментально.
#
# **2)** Работать со своим ботом, запустив скрипт `LastStickerBot.py` на своей машине, следуя инструкциям ниже

# %% [markdown]
# Узнайте свой пользовательский телеграм id и впишите его в переменную `tg_id`. Это можно сделать с помощью бота [@getmyid_bot](https://t.me/getmyid_bot)

# %%
tg_id = YOUR_ID_HERE

# %% [markdown]
# Занесем ваш id в список админов и разрешенных пользователей бота

# %%
with open("bot_config.json", "r") as f:
    bot_config = json.load(f)

bot_config["allowed_ids"].append(tg_id)
bot_config["ADMIN_IDS"].append(tg_id)
    
with open("bot_config.json", "w") as f:
    json.dump(bot_config, f)

# %% [markdown]
# Теперь запустите бота командой в терминале `python3 LastStickerBot.py data`
# Конечно, на месте `data`, вы пишете название папки, в которой лежит база, с которой вы хотите работать

# %% [markdown]
# Теперь откройте своего бота и наберите команду `/start` или `/help`.
# Я постаралась подробно и четко расписать инструкции по работе с ботом, поэтому все, что может понадобиться для ознакомления, доступно по командам `/help` и `/howfilter`

# %% [markdown]
# **О преимуществах бота вкраце:**
#
# - работа с базой с любых устройств, на которые можно установить Telegram
# - одновременно несколько человек могут взаимодействовать с базой данных
# - фильтрация данных на около естественном языке по команде `/filter` (см. `/howfilter`)
# - создание **пользовательских фильтров**: если у вас есть фильтр, по которому вы часто отфильтровываете данные (например, вы часто ищете лоты по определенной коллекции карточек), вы можете сохранить его в базу пользовательских фильтров, придумав ему название (подробнее по команде `/newfilter`)
# - можно не хранить всю огромную таблицу на локальной машине, при этом продолжая с ней работать; при необходимости можно скачать ее в *csv* формате или (только для админов) вообще всю информацию о базе, включая информацию о id разрешенных пользователей, их пользовательских фильтрах и т. д.

# %% [markdown]
# **Additional information:**
#
# Мой бот [@LastStickerStatBot](https://t.me/LastStickerStatBot) пока работает напрямую с Telegram API Server, поэтому имеет ограничение на отправку файлов в размере 50 МБ (не более).
# Учитывая тот факт, что, если пользователь просит выгрузить файл превосходящий этот лимит, бот высылает архив сильно меньшего размера, то пока это ограничение сильно не мешает. Тем более адекватные запросы (на несколько пересечений, например), которые в большинстве своем и делаются, находят относильно мало (несколько сотен) лотов, а размер файла с таким количеством записей далек от лимита.
# Если это ограничение начнет сильно мешать, установлю Local API Server
